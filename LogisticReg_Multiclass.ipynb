# %%
#Logistic Regression - Multiclass Classification
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.datasets import load_digits
digits = load_digits()
print(type(digits))
# Out:
# <class 'sklearn.utils.Bunch'>

# %%
for i in digits:
    print(i, type(i))
# Out:
# data <class 'str'>
# target <class 'str'>
# frame <class 'str'>
# feature_names <class 'str'>
# target_names <class 'str'>
# images <class 'str'>
# DESCR <class 'str'>

# %%
print(digits.data[0])
# Out:
# [ 0.  0.  5. 13.  9.  1.  0.  0.  0.  0. 13. 15. 10. 15.  5.  0.  0.  3.
#  15.  2.  0. 11.  8.  0.  0.  4. 12.  0.  0.  8.  8.  0.  0.  5.  8.  0.
#   0.  9.  8.  0.  0.  4. 11.  0.  1. 12.  7.  0.  0.  2. 14.  5. 10. 12.
#   0.  0.  0.  0.  6. 13. 10.  0.  0.  0.]

# %%
plt.gray()
for i in range(5):
    plt.matshow(digits.images[i])

# %%
from sklearn.model_selection import train_test_split
model = LogisticRegression()
x_train, x_test, y_train, y_test =train_test_split(digits.data , digits.target, train_size = 0.8)

# %%
model.fit(x_train,y_train)
# Out:
# C:\Users\Bhavyashree\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
model.predict(digits.data[:5])
# Out:
# array([0, 1, 2, 3, 4])

# %% [markdown]
# model.score(x_test, y_test)

# %%
model.score(x_test, y_test)
# Out:
# 0.9722222222222222

# %%
#Exercise: Iris_dataset
from sklearn.datasets import load_iris

# %%
dir(load_iris)
# Out:
# ['__annotations__',
#  '__call__',
#  '__class__',
#  '__closure__',
#  '__code__',
#  '__defaults__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__get__',
#  '__getattribute__',
#  '__globals__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__kwdefaults__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__name__',
#  '__ne__',
#  '__new__',
#  '__qualname__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__wrapped__']

# %%
iris_data = load_iris()

# %%
for i in iris_data:
    print(i, type(i))
# Out:
# data <class 'str'>
# target <class 'str'>
# frame <class 'str'>
# target_names <class 'str'>
# DESCR <class 'str'>
# feature_names <class 'str'>
# filename <class 'str'>

# %%
#Shape of Iris_dataset = 150*4
#data - Sepal Length, Sepal Width, Petal Length and Petal Width
#target_names = setosa, versicolor, virginica
#feature_names = sepal length (cm), sepal width (cm), petal length (cm), petal width (cm)

for i in iris_data.data:
    print(i)
# Out:
# [5.1 3.5 1.4 0.2]
# [4.9 3.  1.4 0.2]
# [4.7 3.2 1.3 0.2]
# [4.6 3.1 1.5 0.2]
# [5.  3.6 1.4 0.2]
# [5.4 3.9 1.7 0.4]
# [4.6 3.4 1.4 0.3]
# [5.  3.4 1.5 0.2]
# [4.4 2.9 1.4 0.2]
# [4.9 3.1 1.5 0.1]
# [5.4 3.7 1.5 0.2]
# [4.8 3.4 1.6 0.2]
# [4.8 3.  1.4 0.1]
# [4.3 3.  1.1 0.1]
# [5.8 4.  1.2 0.2]
# [5.7 4.4 1.5 0.4]
# [5.4 3.9 1.3 0.4]
# [5.1 3.5 1.4 0.3]
# [5.7 3.8 1.7 0.3]
# [5.1 3.8 1.5 0.3]
# [5.4 3.4 1.7 0.2]
# [5.1 3.7 1.5 0.4]
# [4.6 3.6 1.  0.2]
# [5.1 3.3 1.7 0.5]
# [4.8 3.4 1.9 0.2]
# [5.  3.  1.6 0.2]
# [5.  3.4 1.6 0.4]
# [5.2 3.5 1.5 0.2]
# [5.2 3.4 1.4 0.2]
# [4.7 3.2 1.6 0.2]
# [4.8 3.1 1.6 0.2]
# [5.4 3.4 1.5 0.4]
# [5.2 4.1 1.5 0.1]
# [5.5 4.2 1.4 0.2]
# [4.9 3.1 1.5 0.2]
# [5.  3.2 1.2 0.2]
# [5.5 3.5 1.3 0.2]
# [4.9 3.6 1.4 0.1]
# [4.4 3.  1.3 0.2]
# [5.1 3.4 1.5 0.2]
# [5.  3.5 1.3 0.3]
# [4.5 2.3 1.3 0.3]
# [4.4 3.2 1.3 0.2]
# [5.  3.5 1.6 0.6]
# [5.1 3.8 1.9 0.4]
# [4.8 3.  1.4 0.3]
# [5.1 3.8 1.6 0.2]
# [4.6 3.2 1.4 0.2]
# [5.3 3.7 1.5 0.2]
# [5.  3.3 1.4 0.2]
# ...

# %%
#target  - Sepal Length, Sepal Width, Petal Length and Petal Width
for i in iris_data.DESCR:
    print(i)
# Out:
# .
# .
#
# _
# i
# r
# i
# s
# _
# d
# a
# t
# a
# s
# e
# t
# :
#
#
#
#
# I
# r
# i
# s
#
# p
# l
# a
# n
# t
# s
#
# d
# a
# t
# a
# s
# e
# t
#
#
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
#
#
#
#
# *
# *
# D
# a
# t
# a
#
# S
# e
# t
#
# C
# h
# a
# r
# a
# c
# t
# e
# r
# i
# s
# t
# i
# c
# s
# :
# *
# *
#
#
#
#
#
#
#
#
# :
# N
# u
# m
# b
# e
# r
#
# o
# f
#
# I
# n
# s
# t
# a
# n
# c
# e
# s
# :
#
# 1
# 5
# 0
#
# (
# 5
# 0
#
# i
# n
#
# e
# a
# c
# h
#
# o
# f
#
# t
# h
# r
# e
# e
#
# c
# l
# a
# s
# s
# e
# s
# )
#
#
#
#
#
#
# :
# N
# u
# m
# b
# e
# r
#
# o
# f
#
# A
# t
# t
# r
# i
# b
# u
# t
# e
# s
# :
#
# 4
#
# n
# u
# m
# e
# r
# i
# c
# ,
#
# p
# r
# e
# d
# i
# c
# t
# i
# v
# e
#
# a
# t
# t
# r
# i
# b
# u
# t
# e
# s
#
# a
# n
# d
#
# t
# h
# e
#
# c
# l
# a
# s
# s
#
#
#
#
#
#
# :
# A
# t
# t
# r
# i
# b
# u
# t
# e
#
# I
# n
# f
# o
# r
# m
# a
# t
# i
# o
# n
# :
#
#
#
#
#
#
#
#
#
#
# -
#
# s
# e
# p
# a
# l
#
# l
# e
# n
# ...

# %%
#Shape of Iris_dataset = 150*4
#data - Sepal Length, Sepal Width, Petal Length and Petal Width
#target_names = setosa, versicolor, virginica
#feature_names = sepal length (cm), sepal width (cm), petal length (cm), petal width (cm)
x = iris_data.data
y = iris_data.target_names

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
#from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,train_size = 0.7)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-65-8e8996521b00> in <module>
#       1 #from sklearn.model_selection import train_test_split
# ----> 2 x_train, x_test, y_train, y_test = train_test_split(x,y,train_size = 0.7)
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_split.py in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2170         raise ValueError("At least one array required as input")
#    2171
# -> 2172     arrays = indexable(*arrays)
#    2173
#    2174     n_samples = _num_samples(arrays[0])
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in indexable(*iterables)
#     297     """
#     298     result = [_make_indexable(X) for X in iterables]
# --> 299     check_consistent_length(*result)
#     300     return result
#     301
#
# ...
